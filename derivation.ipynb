# %%
# draw normal distribution curve
import numpy as np
import matplotlib.pyplot as plt
import math

# %load_ext autoreload
# %autoreload 2
from src.option import OptionContract

mu = 0
sigma = 10
center = 100

x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
xp = x + 100
y = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))

plt.plot(x, y)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
option = OptionContract(90, 5, "Call", "Long")
returns = option.getPriceInformation(x)
print(xp)
plt.plot(xp, returns)
# Out:
# [ 70.          70.60606061  71.21212121  71.81818182  72.42424242
#   73.03030303  73.63636364  74.24242424  74.84848485  75.45454545
#   76.06060606  76.66666667  77.27272727  77.87878788  78.48484848
#   79.09090909  79.6969697   80.3030303   80.90909091  81.51515152
#   82.12121212  82.72727273  83.33333333  83.93939394  84.54545455
#   85.15151515  85.75757576  86.36363636  86.96969697  87.57575758
#   88.18181818  88.78787879  89.39393939  90.          90.60606061
#   91.21212121  91.81818182  92.42424242  93.03030303  93.63636364
#   94.24242424  94.84848485  95.45454545  96.06060606  96.66666667
#   97.27272727  97.87878788  98.48484848  99.09090909  99.6969697
#  100.3030303  100.90909091 101.51515152 102.12121212 102.72727273
#  103.33333333 103.93939394 104.54545455 105.15151515 105.75757576
#  106.36363636 106.96969697 107.57575758 108.18181818 108.78787879
#  109.39393939 110.         110.60606061 111.21212121 111.81818182
#  112.42424242 113.03030303 113.63636364 114.24242424 114.84848485
#  115.45454545 116.06060606 116.66666667 117.27272727 117.87878788
#  118.48484848 119.09090909 119.6969697  120.3030303  120.90909091
#  121.51515152 122.12121212 122.72727273 123.33333333 123.93939394
#  124.54545455 125.15151515 125.75757576 126.36363636 126.96969697
#  127.57575758 128.18181818 128.78787879 129.39393939 130.        ]
